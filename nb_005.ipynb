# %% [markdown]
# Exploring some of the models architechtures currently in use

# %% [markdown]
# models
#
#
# ```mask2former
# albert				maskformer
# align				mbart
# altclip				mbart50
# audio_spectrogram_transformer	mctct
# auto				mega
# bart				megatron_bert
# barthez				megatron_gpt2
# bartpho				mgp_str
# beit				mluke
# bert				mmbt
# bert_generation			mobilebert
# bert_japanese			mobilenet_v1
# bertweet			mobilenet_v2
# big_bird			mobilevit
# bigbird_pegasus			mpnet
# biogpt				mt5
# bit				mvp
# blenderbot			nat
# blenderbot_small		nezha
# blip				nllb
# blip_2				nllb_moe
# bloom				nystromformer
# bort				oneformer
# bridgetower			open_llama
# byt5				openai
# camembert			opt
# canine				owlvit
# chinese_clip			pegasus
# clap				pegasus_x
# clip				perceiver
# clipseg				phobert
# codegen				pix2struct
# conditional_detr		plbart
# convbert			poolformer
# convnext			prophetnet
# convnextv2			qdqbert
# cpm				rag
# cpmant				realm
# ctrl				reformer
# cvt				regnet
# data2vec			rembert
# deberta				resnet
# deberta_v2			retribert
# decision_transformer		roberta
# deformable_detr			roberta_prelayernorm
# deit				roc_bert
# deta				roformer
# detr				rwkv
# dialogpt			sam
# dinat				segformer
# distilbert			sew
# dit				sew_d
# donut				speech_encoder_decoder
# dpr				speech_to_text
# dpt				speech_to_text_2
# efficientformer			speecht5
# efficientnet			splinter
# electra				squeezebert
# encoder_decoder			swin
# ernie				swin2sr
# ernie_m				swinv2
# esm				switch_transformers
# flaubert			t5
# flava				table_transformer
# fnet				tapas
# focalnet			tapex
# fsmt				time_series_transformer
# funnel				timesformer
# git				trajectory_transformer
# glpn				transfo_xl
# gpt2				trocr
# gpt_bigcode			tvlt
# gpt_neo				unispeech
# gpt_neox			unispeech_sat
# gpt_neox_japanese		upernet
# gpt_sw3				van
# gptj				videomae
# gptsan_japanese			vilt
# graphormer			vision_encoder_decoder
# groupvit			vision_text_dual_encoder
# herbert				visual_bert
# hubert				vit
# ibert				vit_hybrid
# imagegpt			vit_mae
# informer			vit_msn
# jukebox				wav2vec2
# layoutlm			wav2vec2_conformer
# layoutlmv2			wav2vec2_phoneme
# layoutlmv3			wav2vec2_with_lm
# layoutxlm			wavlm
# led				whisper
# levit				x_clip
# lilt				xglm
# llama				xlm
# longformer			xlm_prophetnet
# longt5				xlm_roberta
# luke				xlm_roberta_xl
# lxmert				xlnet
# m2m_100				xmod
# marian				yolos
# markuplm			yoso
# ```
